# %%
from sqlalchemy import create_engine
from config import password
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd

# %%
income_df = pd.read_csv("income.csv")
poverty_df = pd.read_csv("poverty.csv")

# %%
income_df.head()
# Out:
#           geoid                   name  B19001001  B19001001, Error  \
# 0       01000US          United States  118825921            229026
# 1     04000US12                Florida    7510882             23856
# 2  05000US12086  Miami-Dade County, FL     858289              3478
# 3  86000US33010                  33010      15146               368
# 4  86000US33012                  33012      23840               484
#
#    B19001002  B19001002, Error  B19001003  B19001003, Error  B19001004  \
# 0    7942251             17662    5768114             16409    5727180
# 1     543790              5187     379751              4814     405792
# 2      85270              1877      54740              1743      51870
# 3       2560               297       2026               289       1515
# 4       3113               426       2666               335       2277
#
#    B19001004, Error        ...         B19001013  B19001013, Error  B19001014  \
# ...

# %%
poverty_df.head()
# Out:
#           geoid                   name  B17001001  B17001001, Error  \
# 0       01000US          United States  313048563             10099
# 1     04000US12                Florida   19858469              2826
# 2  05000US12086  Miami-Dade County, FL    2661803              1536
# 3  86000US33010                  33010      47105              1550
# 4  86000US33012                  33012      75817              2281
#
#    B17001002  B17001002, Error  B17001003  B17001003, Error  B17001004  \
# 0   45650345            281297   20408626            134508    2234987
# 1    3070972             25205    1387764             14239     137558
# 2     505182              8192     222637              4293      20622
# 3      13000              1073       5713               558        461
# 4      19088              1779       8212              1030        662
#
#    B17001004, Error        ...         B17001055  B17001055, Error  B17001056  \
# ...

# %%
poverty_df = poverty_df[['name','B17001001','B17001002','B17001031']]

# %%
poverty_df.head()
# Out:
#                     name  B17001001  B17001002  B17001031
# 0          United States  313048563   45650345  267398218
# 1                Florida   19858469    3070972   16787497
# 2  Miami-Dade County, FL    2661803     505182    2156621
# 3                  33010      47105      13000      34105
# 4                  33012      75817      19088      56729

# %%
poverty_df = poverty_df.rename(columns={"B17001001": "Total Poverty Population" , 
                                      "B17001002" :"Income below poverty level",
                                      "B17001031": "Income above poverty level", 
                                    })
poverty_df.head()
# Out:
#                     name  Total Poverty Population  \
# 0          United States                 313048563
# 1                Florida                  19858469
# 2  Miami-Dade County, FL                   2661803
# 3                  33010                     47105
# 4                  33012                     75817
#
#    Income below poverty level  Income above poverty level
# 0                    45650345                   267398218
# 1                     3070972                    16787497
# 2                      505182                     2156621
# 3                       13000                       34105
# 4                       19088                       56729

# %%
poverty_df = poverty_df.drop([0,1], axis = 0)
poverty_df.head()
# Out:
#                     name  Total Poverty Population  \
# 2  Miami-Dade County, FL                   2661803
# 3                  33010                     47105
# 4                  33012                     75817
# 5                  33013                     33895
# 6                  33014                     40637
#
#    Income below poverty level  Income above poverty level
# 2                      505182                     2156621
# 3                       13000                       34105
# 4                       19088                       56729
# 5                        9315                       24580
# 6                       10959                       29678

# %%
poverty_df = poverty_df.reset_index()

# %%
poverty_df = poverty_df.drop(['index'], axis = 1)

# %%
poverty_df.head()
# Out:
#                     name  Total Poverty Population  \
# 0  Miami-Dade County, FL                   2661803
# 1                  33010                     47105
# 2                  33012                     75817
# 3                  33013                     33895
# 4                  33014                     40637
#
#    Income below poverty level  Income above poverty level
# 0                      505182                     2156621
# 1                       13000                       34105
# 2                       19088                       56729
# 3                        9315                       24580
# 4                       10959                       29678

# %%
poverty_df['Poverty %']= poverty_df["Total Poverty Population"]/poverty_df['Total Poverty Population'][0]

# %%
poverty_df = poverty_df[(poverty_df != 0).all(1)]

# %%
poverty_df.head()
# Out:
#                     name  Total Poverty Population  \
# 0  Miami-Dade County, FL                   2661803
# 1                  33010                     47105
# 2                  33012                     75817
# 3                  33013                     33895
# 4                  33014                     40637
#
#    Income below poverty level  Income above poverty level  Poverty %
# 0                      505182                     2156621   1.000000
# 1                       13000                       34105   0.017697
# 2                       19088                       56729   0.028483
# 3                        9315                       24580   0.012734
# 4                       10959                       29678   0.015267

# %%
income_df = income_df[['name','B19001001','B19001002','B19001003','B19001004','B19001005','B19001006','B19001007','B19001008','B19001009','B19001010','B19001011','B19001012','B19001013','B19001014','B19001015','B19001016']]

# %%
income_df = income_df.rename(columns={"B19001001": "Total Income Population" ,
                                      "B19001002": "Less than $10,000",
                                      "B19001003": "10,000 to 14,999",
                                      "B19001004": "15,000 to 19,999",
                                      "B19001005": "20,000 to 24,999",
                                      "B19001006": "25,000 to 29,999",
                                      "B19001007": "30,000 to 34,999",
                                      "B19001008": "35,000 to 39,999",
                                      "B19001009": "40,000 to 44,999",
                                      "B19001010": "45,000 to 49,999",
                                      "B19001011": "50,000 to 59,999",
                                      "B19001012": "60,000 to 74,999",
                                      "B19001013": "75,000 to 99,999",
                                      "B19001014": "100,000 to 124,999",
                                      "B19001015": "125,000 to 149,999",
                                      "B19001016": "150,000 to 199,999",
                                      "B19001017": "200,000 or More"
                                        })
income_df.head()
# Out:
#                     name  Total Income Population  Less than $10,000  \
# 0          United States                118825921            7942251
# 1                Florida                  7510882             543790
# 2  Miami-Dade County, FL                   858289              85270
# 3                  33010                    15146               2560
# 4                  33012                    23840               3113
#
#    10,000 to 14,999  15,000 to 19,999  20,000 to 24,999  25,000 to 29,999  \
# 0           5768114           5727180           5910725           5619002
# 1            379751            405792            433039            412700
# 2             54740             51870             53234             47810
# 3              2026              1515              1338               990
# 4              2666              2277              1869              1665
#
#    30,000 to 34,999  35,000 to 39,999  40,000 to 44,999  45,000 to 49,999  \
# ...

# %%
income_df = income_df.set_index(['name'])
income_df = income_df.loc[(income_df!=0).any(1)]

# %%
income_df = income_df.reset_index()
income_df.head()
# Out:
#                     name  Total Income Population  Less than $10,000  \
# 0          United States                118825921            7942251
# 1                Florida                  7510882             543790
# 2  Miami-Dade County, FL                   858289              85270
# 3                  33010                    15146               2560
# 4                  33012                    23840               3113
#
#    10,000 to 14,999  15,000 to 19,999  20,000 to 24,999  25,000 to 29,999  \
# 0           5768114           5727180           5910725           5619002
# 1            379751            405792            433039            412700
# 2             54740             51870             53234             47810
# 3              2026              1515              1338               990
# 4              2666              2277              1869              1665
#
#    30,000 to 34,999  35,000 to 39,999  40,000 to 44,999  45,000 to 49,999  \
# ...

# %%
income_df = income_df.drop([0,1], axis = 0)
income_df.head()
# Out:
#                     name  Total Income Population  Less than $10,000  \
# 2  Miami-Dade County, FL                   858289              85270
# 3                  33010                    15146               2560
# 4                  33012                    23840               3113
# 5                  33013                     9578               1323
# 6                  33014                    13800               2046
#
#    10,000 to 14,999  15,000 to 19,999  20,000 to 24,999  25,000 to 29,999  \
# 2             54740             51870             53234             47810
# 3              2026              1515              1338               990
# 4              2666              2277              1869              1665
# 5               970              1003               832               530
# 6              1456               828               959               782
#
#    30,000 to 34,999  35,000 to 39,999  40,000 to 44,999  45,000 to 49,999  \
# ...

# %%
both_df = pd.merge(poverty_df, income_df, on='name')

# %%
both_df.head()
# Out:
#                     name  Total Poverty Population  \
# 0  Miami-Dade County, FL                   2661803
# 1                  33010                     47105
# 2                  33012                     75817
# 3                  33013                     33895
# 4                  33014                     40637
#
#    Income below poverty level  Income above poverty level  Poverty %  \
# 0                      505182                     2156621   1.000000
# 1                       13000                       34105   0.017697
# 2                       19088                       56729   0.028483
# 3                        9315                       24580   0.012734
# 4                       10959                       29678   0.015267
#
#    Total Income Population  Less than $10,000  10,000 to 14,999  \
# 0                   858289              85270             54740
# 1                    15146               2560              2026
# ...

# %%
#Connect to local database
rds_connection_string = f"root:{password}@localhost/services_311_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
#Check tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# ~\Anaconda\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Anaconda\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# ~\Anaconda\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
# ...

# %%
#Load df into table in mysql
both_df.to_sql(name='census', con=engine, if_exists='replace', index=False)

# %%
#Preview table to verify load worked
pd.read_sql_query('select * from census', con=engine).head()

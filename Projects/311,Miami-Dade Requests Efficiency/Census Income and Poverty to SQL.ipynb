# %%
from sqlalchemy import create_engine
from config import password
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd
import numpy as np

# %%
income_df = pd.read_csv("income.csv")
poverty_df = pd.read_csv("poverty.csv")

# %%
income_df.head()
# Out:
#           geoid                   name  B19001001  B19001001, Error  \
# 0       01000US          United States  118825921            229026
# 1     04000US12                Florida    7510882             23856
# 2  05000US12086  Miami-Dade County, FL     858289              3478
# 3  86000US33010                  33010      15146               368
# 4  86000US33012                  33012      23840               484
#
#    B19001002  B19001002, Error  B19001003  B19001003, Error  B19001004  \
# 0    7942251             17662    5768114             16409    5727180
# 1     543790              5187     379751              4814     405792
# 2      85270              1877      54740              1743      51870
# 3       2560               297       2026               289       1515
# 4       3113               426       2666               335       2277
#
#    B19001004, Error        ...         B19001013  B19001013, Error  B19001014  \
# ...

# %%
poverty_df.head()
# Out:
#           geoid                   name  B17001001  B17001001, Error  \
# 0       01000US          United States  313048563             10099
# 1     04000US12                Florida   19858469              2826
# 2  05000US12086  Miami-Dade County, FL    2661803              1536
# 3  86000US33010                  33010      47105              1550
# 4  86000US33012                  33012      75817              2281
#
#    B17001002  B17001002, Error  B17001003  B17001003, Error  B17001004  \
# 0   45650345            281297   20408626            134508    2234987
# 1    3070972             25205    1387764             14239     137558
# 2     505182              8192     222637              4293      20622
# 3      13000              1073       5713               558        461
# 4      19088              1779       8212              1030        662
#
#    B17001004, Error        ...         B17001055  B17001055, Error  B17001056  \
# ...

# %%
poverty_df = poverty_df[['name','B17001001','B17001002','B17001031']]

# %%
poverty_df.head()
# Out:
#                     name  B17001001  B17001002  B17001031
# 0          United States  313048563   45650345  267398218
# 1                Florida   19858469    3070972   16787497
# 2  Miami-Dade County, FL    2661803     505182    2156621
# 3                  33010      47105      13000      34105
# 4                  33012      75817      19088      56729

# %%
poverty_df = poverty_df.rename(columns={"B17001001": "Total_Poverty_Population" , 
                                      "B17001002" :"Income_below_poverty_level",
                                      "B17001031": "Income_above_poverty_level", 
                                    })
poverty_df.head()
# Out:
#                     name  Total_Poverty_Population  \
# 0          United States                 313048563
# 1                Florida                  19858469
# 2  Miami-Dade County, FL                   2661803
# 3                  33010                     47105
# 4                  33012                     75817
#
#    Income_below_poverty_level  Income_above_poverty_level
# 0                    45650345                   267398218
# 1                     3070972                    16787497
# 2                      505182                     2156621
# 3                       13000                       34105
# 4                       19088                       56729

# %%
poverty_df = poverty_df.drop([0,1], axis = 0)
poverty_df.head()
# Out:
#                     name  Total_Poverty_Population  \
# 2  Miami-Dade County, FL                   2661803
# 3                  33010                     47105
# 4                  33012                     75817
# 5                  33013                     33895
# 6                  33014                     40637
#
#    Income_below_poverty_level  Income_above_poverty_level
# 2                      505182                     2156621
# 3                       13000                       34105
# 4                       19088                       56729
# 5                        9315                       24580
# 6                       10959                       29678

# %%
poverty_df = poverty_df.reset_index()

# %%
poverty_df = poverty_df.drop(['index'], axis = 1)

# %%
poverty_df.head()
# Out:
#                     name  Total_Poverty_Population  \
# 0  Miami-Dade County, FL                   2661803
# 1                  33010                     47105
# 2                  33012                     75817
# 3                  33013                     33895
# 4                  33014                     40637
#
#    Income_below_poverty_level  Income_above_poverty_level
# 0                      505182                     2156621
# 1                       13000                       34105
# 2                       19088                       56729
# 3                        9315                       24580
# 4                       10959                       29678

# %%
poverty_df['Poverty_perc']=(poverty_df["Income_below_poverty_level"])/poverty_df['Total_Poverty_Population']

# %%
poverty_df = poverty_df[(poverty_df != 0).all(1)]

# %%
poverty_df.head()
# Out:
#                     name  Total_Poverty_Population  \
# 0  Miami-Dade County, FL                   2661803
# 1                  33010                     47105
# 2                  33012                     75817
# 3                  33013                     33895
# 4                  33014                     40637
#
#    Income_below_poverty_level  Income_above_poverty_level  Poverty_perc
# 0                      505182                     2156621      0.189789
# 1                       13000                       34105      0.275979
# 2                       19088                       56729      0.251764
# 3                        9315                       24580      0.274819
# 4                       10959                       29678      0.269680

# %%
income_df = income_df[['name','B19001001','B19001002','B19001003','B19001004','B19001005','B19001006','B19001007','B19001008','B19001009','B19001010','B19001011','B19001012','B19001013','B19001014','B19001015','B19001016','B19001017']]

# %%
income_df = income_df.rename(columns={"B19001001": "Total_Income_Population" ,
                                      "B19001002": "10,000",
                                      "B19001003": "14,999",
                                      "B19001004": "19,999",
                                      "B19001005": "24,999",
                                      "B19001006": "29,999",
                                      "B19001007": "34,999",
                                      "B19001008": "39,999",
                                      "B19001009": "44,999",
                                      "B19001010": "49,999",
                                      "B19001011": "59,999",
                                      "B19001012": "74,999",
                                      "B19001013": "99,999",
                                      "B19001014": "124,999",
                                      "B19001015": "149,999",
                                      "B19001016": "199,999",
                                      "B19001017": "200,000"
                                        })
income_df.head()
# Out:
#                     name  Total_Income_Population   10,000   14,999   19,999  \
# 0          United States                118825921  7942251  5768114  5727180
# 1                Florida                  7510882   543790   379751   405792
# 2  Miami-Dade County, FL                   858289    85270    54740    51870
# 3                  33010                    15146     2560     2026     1515
# 4                  33012                    23840     3113     2666     2277
#
#     24,999   29,999   34,999   39,999   44,999   49,999   59,999    74,999  \
# 0  5910725  5619002  5711286  5332778  5354520  4725195  9181800  11818514
# 1   433039   412700   411672   389048   382555   329970   624646    754759
# 2    53234    47810    43412    41367    40931    36480    63248     77426
# 3     1338      990     1173      893      620      530      955       897
# 4     1869     1665     1369     1208     1173     1159     1869      1845
#
#      99,999   124,999  149,999  199,999  200,000
# ...

# %%
income_df = income_df.set_index(['name'])
income_df = income_df.loc[(income_df!=0).any(1)]

# %%
income_df = income_df.reset_index()
income_df.head()
# Out:
#                     name  Total_Income_Population   10,000   14,999   19,999  \
# 0          United States                118825921  7942251  5768114  5727180
# 1                Florida                  7510882   543790   379751   405792
# 2  Miami-Dade County, FL                   858289    85270    54740    51870
# 3                  33010                    15146     2560     2026     1515
# 4                  33012                    23840     3113     2666     2277
#
#     24,999   29,999   34,999   39,999   44,999   49,999   59,999    74,999  \
# 0  5910725  5619002  5711286  5332778  5354520  4725195  9181800  11818514
# 1   433039   412700   411672   389048   382555   329970   624646    754759
# 2    53234    47810    43412    41367    40931    36480    63248     77426
# 3     1338      990     1173      893      620      530      955       897
# 4     1869     1665     1369     1208     1173     1159     1869      1845
#
#      99,999   124,999  149,999  199,999  200,000
# ...

# %%
income_df = income_df.drop([0,1], axis = 0)
income_df.head()
# Out:
#                     name  Total_Income_Population  10,000  14,999  19,999  \
# 2  Miami-Dade County, FL                   858289   85270   54740   51870
# 3                  33010                    15146    2560    2026    1515
# 4                  33012                    23840    3113    2666    2277
# 5                  33013                     9578    1323     970    1003
# 6                  33014                    13800    2046    1456     828
#
#    24,999  29,999  34,999  39,999  44,999  49,999  59,999  74,999  99,999  \
# 2   53234   47810   43412   41367   40931   36480   63248   77426   87953
# 3    1338     990    1173     893     620     530     955     897     878
# 4    1869    1665    1369    1208    1173    1159    1869    1845    1749
# 5     832     530     450     442     392     451     790     867     719
# 6     959     782     485     975     747     371     809    1210    1052
#
#    124,999  149,999  199,999  200,000
# ...

# %%
income_df.head()
# Out:
#                     name  Total_Income_Population  10,000  14,999  19,999  \
# 2  Miami-Dade County, FL                   858289   85270   54740   51870
# 3                  33010                    15146    2560    2026    1515
# 4                  33012                    23840    3113    2666    2277
# 5                  33013                     9578    1323     970    1003
# 6                  33014                    13800    2046    1456     828
#
#    24,999  29,999  34,999  39,999  44,999  49,999  59,999  74,999  99,999  \
# 2   53234   47810   43412   41367   40931   36480   63248   77426   87953
# 3    1338     990    1173     893     620     530     955     897     878
# 4    1869    1665    1369    1208    1173    1159    1869    1845    1749
# 5     832     530     450     442     392     451     790     867     719
# 6     959     782     485     975     747     371     809    1210    1052
#
#    124,999  149,999  199,999  200,000
# ...

# %%
zip_income = income_df
zip_income.head()
# Out:
#                     name  Total_Income_Population  10,000  14,999  19,999  \
# 2  Miami-Dade County, FL                   858289   85270   54740   51870
# 3                  33010                    15146    2560    2026    1515
# 4                  33012                    23840    3113    2666    2277
# 5                  33013                     9578    1323     970    1003
# 6                  33014                    13800    2046    1456     828
#
#    24,999  29,999  34,999  39,999  44,999  49,999  59,999  74,999  99,999  \
# 2   53234   47810   43412   41367   40931   36480   63248   77426   87953
# 3    1338     990    1173     893     620     530     955     897     878
# 4    1869    1665    1369    1208    1173    1159    1869    1845    1749
# 5     832     530     450     442     392     451     790     867     719
# 6     959     782     485     975     747     371     809    1210    1052
#
#    124,999  149,999  199,999  200,000
# ...

# %%
zip_income = income_df.drop('Total_Income_Population', axis = 1)
zip_income.head()
# Out:
#                     name  10,000  14,999  19,999  24,999  29,999  34,999  \
# 2  Miami-Dade County, FL   85270   54740   51870   53234   47810   43412
# 3                  33010    2560    2026    1515    1338     990    1173
# 4                  33012    3113    2666    2277    1869    1665    1369
# 5                  33013    1323     970    1003     832     530     450
# 6                  33014    2046    1456     828     959     782     485
#
#    39,999  44,999  49,999  59,999  74,999  99,999  124,999  149,999  199,999  \
# 2   41367   40931   36480   63248   77426   87953    58400    33702    36256
# 3     893     620     530     955     897     878      371      203      141
# 4    1208    1173    1159    1869    1845    1749      868      398      398
# 5     442     392     451     790     867     719      448      199      107
# 6     975     747     371     809    1210    1052      857      338      500
#
#    200,000
# 2    46190
# 3       56
# 4      214
# 5       55
# ...

# %%
zip_income = zip_income.drop((zip_income.index[0]))

# %%
zip_income.head()
# Out:
#     name  10,000  14,999  19,999  24,999  29,999  34,999  39,999  44,999  \
# 3  33010    2560    2026    1515    1338     990    1173     893     620
# 4  33012    3113    2666    2277    1869    1665    1369    1208    1173
# 5  33013    1323     970    1003     832     530     450     442     392
# 6  33014    2046    1456     828     959     782     485     975     747
# 7  33015    2229    1261     842    1208    1010     877    1369    1147
#
#    49,999  59,999  74,999  99,999  124,999  149,999  199,999  200,000
# 3     530     955     897     878      371      203      141       56
# 4    1159    1869    1845    1749      868      398      398      214
# 5     451     790     867     719      448      199      107       55
# 6     371     809    1210    1052      857      338      500      385
# 7     790    2082    2361    2588     1586      815      520      368

# %%
zip_income = zip_income.set_index('name')
zip_income.head()
# Out:
#        10,000  14,999  19,999  24,999  29,999  34,999  39,999  44,999  49,999  \
# name
# 33010    2560    2026    1515    1338     990    1173     893     620     530
# 33012    3113    2666    2277    1869    1665    1369    1208    1173    1159
# 33013    1323     970    1003     832     530     450     442     392     451
# 33014    2046    1456     828     959     782     485     975     747     371
# 33015    2229    1261     842    1208    1010     877    1369    1147     790
#
#        59,999  74,999  99,999  124,999  149,999  199,999  200,000
# name
# 33010     955     897     878      371      203      141       56
# 33012    1869    1845    1749      868      398      398      214
# 33013     790     867     719      448      199      107       55
# 33014     809    1210    1052      857      338      500      385
# 33015    2082    2361    2588     1586      815      520      368

# %%
cumu_sum = []
total = []
sum_income = zip_income
cumu_income =zip_income
sum_income['sum'] = zip_income.sum(axis=1)
zip_income.head()
# Out:
#        10,000  14,999  19,999  24,999  29,999  34,999  39,999  44,999  49,999  \
# name
# 33010    2560    2026    1515    1338     990    1173     893     620     530
# 33012    3113    2666    2277    1869    1665    1369    1208    1173    1159
# 33013    1323     970    1003     832     530     450     442     392     451
# 33014    2046    1456     828     959     782     485     975     747     371
# 33015    2229    1261     842    1208    1010     877    1369    1147     790
#
#        59,999  74,999  99,999  124,999  149,999  199,999  200,000    sum
# name
# 33010     955     897     878      371      203      141       56  15146
# 33012    1869    1845    1749      868      398      398      214  23840
# 33013     790     867     719      448      199      107       55   9578
# 33014     809    1210    1052      857      338      500      385  13800
# 33015    2082    2361    2588     1586      815      520      368  21053

# %%
cumu_sum =cumu_income.cumsum(axis=1)
cumu_sum.head()
# Out:
#        10,000  14,999  19,999  24,999  29,999  34,999  39,999  44,999  49,999  \
# name
# 33010    2560    4586    6101    7439    8429    9602   10495   11115   11645
# 33012    3113    5779    8056    9925   11590   12959   14167   15340   16499
# 33013    1323    2293    3296    4128    4658    5108    5550    5942    6393
# 33014    2046    3502    4330    5289    6071    6556    7531    8278    8649
# 33015    2229    3490    4332    5540    6550    7427    8796    9943   10733
#
#        59,999  74,999  99,999  124,999  149,999  199,999  200,000    sum
# name
# 33010   12600   13497   14375    14746    14949    15090    15146  30292
# 33012   18368   20213   21962    22830    23228    23626    23840  47680
# 33013    7183    8050    8769     9217     9416     9523     9578  19156
# 33014    9458   10668   11720    12577    12915    13415    13800  27600
# 33015   12815   15176   17764    19350    20165    20685    21053  42106

# %%
income_df.head()
# Out:
#                     name  Total_Income_Population  10,000  14,999  19,999  \
# 2  Miami-Dade County, FL                   858289   85270   54740   51870
# 3                  33010                    15146    2560    2026    1515
# 4                  33012                    23840    3113    2666    2277
# 5                  33013                     9578    1323     970    1003
# 6                  33014                    13800    2046    1456     828
#
#    24,999  29,999  34,999  39,999  44,999  49,999  59,999  74,999  99,999  \
# 2   53234   47810   43412   41367   40931   36480   63248   77426   87953
# 3    1338     990    1173     893     620     530     955     897     878
# 4    1869    1665    1369    1208    1173    1159    1869    1845    1749
# 5     832     530     450     442     392     451     790     867     719
# 6     959     782     485     975     747     371     809    1210    1052
#
#    124,999  149,999  199,999  200,000
# ...

# %%
both_df = pd.merge(poverty_df, income_df, on='name')

# %%
both_df.head()
# Out:
#                     name  Total_Poverty_Population  \
# 0  Miami-Dade County, FL                   2661803
# 1                  33010                     47105
# 2                  33012                     75817
# 3                  33013                     33895
# 4                  33014                     40637
#
#    Income_below_poverty_level  Income_above_poverty_level  Poverty_perc  \
# 0                      505182                     2156621      0.189789
# 1                       13000                       34105      0.275979
# 2                       19088                       56729      0.251764
# 3                        9315                       24580      0.274819
# 4                       10959                       29678      0.269680
#
#    Total_Income_Population  10,000  14,999  19,999  24,999   ...     39,999  \
# 0                   858289   85270   54740   51870   53234   ...      41367
# ...

# %%
both_df = both_df.reset_index()

# %%
both_df = both_df.rename(columns={"index": "id"})
both_df.head()
# Out:
#    id                   name  Total_Poverty_Population  \
# 0   0  Miami-Dade County, FL                   2661803
# 1   1                  33010                     47105
# 2   2                  33012                     75817
# 3   3                  33013                     33895
# 4   4                  33014                     40637
#
#    Income_below_poverty_level  Income_above_poverty_level  Poverty_perc  \
# 0                      505182                     2156621      0.189789
# 1                       13000                       34105      0.275979
# 2                       19088                       56729      0.251764
# 3                        9315                       24580      0.274819
# 4                       10959                       29678      0.269680
#
#    Total_Income_Population  10,000  14,999  19,999   ...     39,999  44,999  \
# 0                   858289   85270   54740   51870   ...      41367   40931
# ...

# %%
#Connect to local database
rds_connection_string = f"root:{password}@localhost/services_311_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
#Check tables
engine.table_names()
# Out:
# ['census',
#  'city_avg_0',
#  'city_efficiency',
#  'requests_311',
#  'service_chart',
#  'total_avg_0',
#  'zip_avg_0',
#  'zip_efficiency']

# %%
#Load df into table in mysql
both_df.to_sql(name='census', con=engine, if_exists='replace', index=False)

# %%
#Preview table to verify load worked
pd.read_sql_query('select * from census', con=engine).head()
# Out:
#    id                   name  Total_Poverty_Population  \
# 0   0  Miami-Dade County, FL                   2661803
# 1   1                  33010                     47105
# 2   2                  33012                     75817
# 3   3                  33013                     33895
# 4   4                  33014                     40637
#
#    Income_below_poverty_level  Income_above_poverty_level  Poverty_perc  \
# 0                      505182                     2156621      0.189789
# 1                       13000                       34105      0.275979
# 2                       19088                       56729      0.251764
# 3                        9315                       24580      0.274819
# 4                       10959                       29678      0.269680
#
#    Total_Income_Population  10,000  14,999  19,999   ...     39,999  44,999  \
# 0                   858289   85270   54740   51870   ...      41367   40931
# ...
